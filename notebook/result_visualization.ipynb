# %%
import sys
sys.path.append('/Users/diegofiori/Desktop/epfl/master_thesis/master_thesis/')
from utils import plot_slice, plot_slice_diagram
from input_reader import read_simulation_file, get_all_time_ids

# %%
data_path = '/Users/diegofiori/Desktop/epfl/master_thesis/Reverse/'
result_path = '/Users/diegofiori/Desktop/epfl/master_thesis/results/'

# %%
list_ = get_all_time_ids(data_path)[:2]

# %%
slices = read_simulation_file(data_path, 'temperature', list_)

# %%
slices.shape
# Out:
# (160, 244, 324)

# %%
plot_slice(slices[0])

# %%
plot_slice_diagram(slices[0])

# %%
list_ = get_all_time_ids(data_path)[-2:]

slices = read_simulation_file(data_path, 'temperature', list_)

slices.shape
# Out:
# (160, 244, 324)

# %%
plot_slice(slices[80])

# %%
plot_slice_diagram(slices[80])
