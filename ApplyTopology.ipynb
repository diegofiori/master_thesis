# %%
import sys
sys.path.append('/Users/diegofiori/Desktop/epfl/master_thesis/master_thesis')
from simulation import Simulation
from topological_tools import VlasovGiotto
# %load_ext autoreload
# %autoreload 2

# %%
path = '/Users/diegofiori/Desktop/epfl/master_thesis/Reverse/'

# %%
vg = VlasovGiotto(path)

# %%
df = vg.get_topological_features()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#  10%|█         | 1/10 [00:31<04:42, 31.44s/it]
#
#  20%|██        | 2/10 [01:06<04:20, 32.52s/it]
#
#  30%|███       | 3/10 [01:48<04:07, 35.29s/it]
#
#  40%|████      | 4/10 [02:06<03:00, 30.05s/it]
#
#  50%|█████     | 5/10 [02:55<02:59, 35.96s/it]
#
#  60%|██████    | 6/10 [03:51<02:47, 41.89s/it]
#
#  70%|███████   | 7/10 [04:25<01:58, 39.57s/it]
#
#  80%|████████  | 8/10 [05:56<01:49, 54.96s/it]
#
#  90%|█████████ | 9/10 [06:55<00:56, 56.16s/it]
#
# 100%|██████████| 10/10 [07:29<00:00, 44.98s/it]

# %%
df
# Out:
#          sup_0_0  sup_0_0.7853981633974483  sup_0_1.5707963267948966  \
# 001586  0.611363                  0.645259                  0.602422
# 001587  0.076310                  0.338798                  0.604260
# 001588  0.021042                  0.519879                  0.004881
# 001589  0.674048                 -0.026419                  0.052343
# 001590  0.377811                  0.316973                  0.263730
# ...          ...                       ...                       ...
# 001601  0.832533                  0.911128                  0.869436
# 001602  0.909892                  0.488755                  0.460483
# 001603  0.621920                  0.451522                  0.425892
# 001604  0.493151                  0.475576                  0.566798
# 001605  0.602306                  0.713153                  0.751033
#
#         sup_0_2.356194490192345  sup_0_3.141592653589793  \
# 001586                 0.600417                 0.652529
# 001587                 0.573466                 0.541344
# 001588                 0.078744                 0.067245
# 001589                 0.035591                 0.020377
# 001590                 0.231743                 0.155143
# ...                         ...                      ...
# 001601                 0.816582                 0.855725
# 001602                 0.432847                 0.413552
# 001603                 0.603709                 0.481845
# 001604                 0.539519                 0.850804
# 001605                 0.787284                 0.603134
#
#         sup_0_3.9269908169872414  sup_0_4.71238898038469  \
# 001586                  0.107846                0.077364
# 001587                  0.016189                0.079548
# 001588                  0.054963                0.043275
# 001589                  0.005691                0.719062
# 001590                  0.014383                0.000000
# ...                          ...                     ...
# 001601                  0.835693                0.678906
# 001602                  0.575284                0.551045
# 001603                  0.798140                0.752959
# 001604                  0.892070                0.878676
# 001605                  0.635526                0.559813
#
#         sup_0_5.497787143782138    inf_00  inf_00.7853981633974483  ...  \
# 001586                 0.113290 -2.144752                -2.144672  ...
# 001587                 0.085061 -2.139273                -2.139192  ...
# 001588                 0.033634 -2.134027                -2.133955  ...
# 001589                 0.696407 -2.128911                -2.128857  ...
# 001590                 0.411108 -2.123972                -2.123944  ...
# ...                         ...       ...                      ...  ...
# 001601                 0.661691 -2.056716                -2.056901  ...
# 001602                 0.532871 -2.051009                -2.051172  ...
# 001603                 0.669054 -2.045535                -2.045630  ...
# 001604                 0.807413 -2.040403                -2.040544  ...
# 001605                 0.618274 -2.035679                -2.035849  ...
#
#         betti_4.71238898038469  betti_5.497787143782138    heat_0  \
# 001586               14.662878                14.317821  1.311035
# 001587               12.041595                13.114877  1.257319
# 001588               13.114877                13.000000  0.946853
# 001589               12.328828                12.124356  1.068843
# 001590               12.449900                12.489996  1.139034
# ...                        ...                      ...       ...
# 001601               13.674794                14.071247  1.096880
# 001602               12.609520                12.489996  1.371329
# 001603               14.628739                14.866069  1.663496
# 001604               14.933185                14.798649  1.385157
# 001605               14.071247                12.884099  1.202290
#
#         heat_0.7853981633974483  heat_1.5707963267948966  \
# 001586                 0.964122                 0.903070
# 001587                 0.977160                 1.098538
# 001588                 1.092943                 0.835495
# 001589                 1.139618                 1.015549
# 001590                 1.016410                 1.059582
# ...                         ...                      ...
# 001601                 1.443937                 1.473469
# 001602                 1.267137                 1.360700
# 001603                 1.290405                 1.523457
# 001604                 1.524163                 1.280947
# 001605                 1.136082                 1.305307
#
#         heat_2.356194490192345  heat_3.141592653589793  \
# 001586                0.809012                1.038098
# 001587                1.356970                1.056362
# 001588                1.009254                1.282531
# 001589                1.035486                1.037475
# 001590                1.143954                1.182299
# ...                        ...                     ...
# 001601                1.072422                1.484076
# 001602                1.318618                1.451213
# 001603                1.694966                1.519450
# 001604                1.447915                1.305542
# 001605                1.302272                1.557351
#
#         heat_3.9269908169872414  heat_4.71238898038469  heat_5.497787143782138
# 001586                 1.462280               0.959890                1.140967
# 001587                 1.225746               0.933441                1.024807
# 001588                 0.841036               1.260864                0.760005
# 001589                 1.159821               0.871703                1.004102
# 001590                 1.149389               0.876242                0.815057
# ...                         ...                    ...                     ...
# 001601                 1.318304               1.573642                1.328750
# 001602                 1.518046               1.169254                1.294782
# 001603                 1.651020               1.329819                1.529220
# 001604                 1.452757               1.757461                1.784571
# 001605                 1.754717               1.288466                1.244761
#
# [63 rows x 72 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.heat_0)

# %%
vg = VlasovGiotto(path)
df = vg.add_physical_features()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#  10%|█         | 1/10 [00:03<00:34,  3.82s/it]
#
#
#
#  20%|██        | 2/10 [00:07<00:30,  3.80s/it]
#
#
#
#  30%|███       | 3/10 [00:11<00:26,  3.82s/it]
#
#
#
#  40%|████      | 4/10 [00:13<00:19,  3.31s/it]
#
#
#
#  50%|█████     | 5/10 [00:18<00:19,  3.81s/it]
#
#
#
#  60%|██████    | 6/10 [00:23<00:16,  4.18s/it]
#
#
#
#  70%|███████   | 7/10 [00:27<00:12,  4.11s/it]
#
#
#
#  80%|████████  | 8/10 [00:33<00:09,  4.63s/it]
#
#
#
#  90%|█████████ | 9/10 [00:39<00:05,  5.16s/it]
#
#
#
# 100%|██████████| 10/10 [00:45<00:00,  4.53s/it]

# %%
df
# Out:
#         v_pari_energy  pressure_energy  electrostatic_energy  magnetic_energy  \
# 001586    298459936.0     8.827066e+09          2.137481e+08              0.0
# 001587    293689792.0     8.868789e+09          2.301409e+08              0.0
# 001588    289034368.0     8.910569e+09          2.495331e+08              0.0
# 001589    285795072.0     8.953183e+09          2.735518e+08              0.0
# 001590    284338560.0     8.997167e+09          3.030650e+08              0.0
# ...               ...              ...                   ...              ...
# 001601    279299424.0     9.575882e+09          3.641453e+08              0.0
# 001602    277397792.0     9.626330e+09          3.512855e+08              0.0
# 001603    275658912.0     9.672675e+09          3.120121e+08              0.0
# 001604    274469248.0     9.711355e+09          2.609314e+08              0.0
# 001605    273920704.0     9.745953e+09          2.181670e+08              0.0
#
#         total_energy
# 001586  9.339275e+09
# 001587  9.392619e+09
# 001588  9.449137e+09
# 001589  9.512530e+09
# 001590  9.584570e+09
# ...              ...
# 001601  1.021933e+10
# 001602  1.025501e+10
# 001603  1.026035e+10
# 001604  1.024676e+10
# 001605  1.023804e+10
#
# [63 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
new_df = df.reset_index()
plt.figure()
plt.plot(new_df.total_energy)
plt.figure()
plt.plot(new_df.pressure_energy)
plt.show()

# %%
vg = VlasovGiotto(path)
df = vg.run()
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#  10%|█         | 1/10 [00:31<04:39, 31.04s/it]
#
#
#
#  20%|██        | 2/10 [01:09<04:25, 33.23s/it]
#
#
#
#  30%|███       | 3/10 [01:53<04:15, 36.47s/it]
#
#
#
#  40%|████      | 4/10 [02:14<03:11, 31.99s/it]
#
#
#
#  50%|█████     | 5/10 [03:10<03:14, 38.97s/it]
#
#
#
#  60%|██████    | 6/10 [04:08<02:58, 44.73s/it]
#
#
#
#  70%|███████   | 7/10 [04:42<02:04, 41.54s/it]
#
#
#
#  80%|████████  | 8/10 [06:13<01:52, 56.40s/it]
#
#
#
#  90%|█████████ | 9/10 [07:12<00:57, 57.18s/it]
#
#
#
# 100%|██████████| 10/10 [07:46<00:00, 46.67s/it]
#
#
#
#
#   0%|          | 0/10 [00:00<?, ?it/s]
#
#
#
#  10%|█         | 1/10 [00:03<00:30,  3.36s/it]
#
#
#
#  20%|██        | 2/10 [00:07<00:28,  3.59s/it]
#
#
#
#  30%|███       | 3/10 [00:11<00:26,  3.72s/it]
#
#
#
#  40%|████      | 4/10 [00:13<00:19,  3.28s/it]
#
#
#
#  50%|█████     | 5/10 [00:18<00:18,  3.76s/it]
#
#
#
#  60%|██████    | 6/10 [00:23<00:16,  4.14s/it]
#
#
#
#  70%|███████   | 7/10 [00:27<00:12,  4.11s/it]
#
#
#
#  80%|████████  | 8/10 [00:33<00:09,  4.61s/it]
#
#
#
#  90%|█████████ | 9/10 [00:39<00:05,  5.02s/it]
#
#
#
# 100%|██████████| 10/10 [00:43<00:00,  4.33s/it]

# %%
df
# Out:
#          sup_0_0  sup_0_0.7853981633974483  sup_0_1.5707963267948966  \
# 001586  0.611363                  0.645259                  0.602422
# 001587  0.076310                  0.338798                  0.604260
# 001588  0.021042                  0.519879                  0.004881
# 001589  0.674048                 -0.026419                  0.052343
# 001590  0.377811                  0.316973                  0.263730
# ...          ...                       ...                       ...
# 001601  0.832533                  0.911128                  0.869436
# 001602  0.909892                  0.488755                  0.460483
# 001603  0.621920                  0.451522                  0.425892
# 001604  0.493151                  0.475576                  0.566798
# 001605  0.602306                  0.713153                  0.751033
#
#         sup_0_2.356194490192345  sup_0_3.141592653589793  \
# 001586                 0.600417                 0.652529
# 001587                 0.573466                 0.541344
# 001588                 0.078744                 0.067245
# 001589                 0.035591                 0.020377
# 001590                 0.231743                 0.155143
# ...                         ...                      ...
# 001601                 0.816582                 0.855725
# 001602                 0.432847                 0.413552
# 001603                 0.603709                 0.481845
# 001604                 0.539519                 0.850804
# 001605                 0.787284                 0.603134
#
#         sup_0_3.9269908169872414  sup_0_4.71238898038469  \
# 001586                  0.107846                0.077364
# 001587                  0.016189                0.079548
# 001588                  0.054963                0.043275
# 001589                  0.005691                0.719062
# 001590                  0.014383                0.000000
# ...                          ...                     ...
# 001601                  0.835693                0.678906
# 001602                  0.575284                0.551045
# 001603                  0.798140                0.752959
# 001604                  0.892070                0.878676
# 001605                  0.635526                0.559813
#
#         sup_0_5.497787143782138   inf_0_0  inf_0_0.7853981633974483  ...  \
# 001586                 0.113290 -2.144752                 -2.144672  ...
# 001587                 0.085061 -2.139273                 -2.139192  ...
# 001588                 0.033634 -2.134027                 -2.133955  ...
# 001589                 0.696407 -2.128911                 -2.128857  ...
# 001590                 0.411108 -2.123972                 -2.123944  ...
# ...                         ...       ...                       ...  ...
# 001601                 0.661691 -2.056716                 -2.056901  ...
# 001602                 0.532871 -2.051009                 -2.051172  ...
# 001603                 0.669054 -2.045535                 -2.045630  ...
# 001604                 0.807413 -2.040403                 -2.040544  ...
# 001605                 0.618274 -2.035679                 -2.035849  ...
#
#         heat_2.356194490192345  heat_3.141592653589793  \
# 001586                0.809012                1.038098
# 001587                1.356970                1.056362
# 001588                1.009254                1.282531
# 001589                1.035486                1.037475
# 001590                1.143954                1.182299
# ...                        ...                     ...
# 001601                1.072422                1.484076
# 001602                1.318618                1.451213
# 001603                1.694966                1.519450
# 001604                1.447915                1.305542
# 001605                1.302272                1.557351
#
#         heat_3.9269908169872414  heat_4.71238898038469  \
# 001586                 1.462280               0.959890
# 001587                 1.225746               0.933441
# 001588                 0.841036               1.260864
# 001589                 1.159821               0.871703
# 001590                 1.149389               0.876242
# ...                         ...                    ...
# 001601                 1.318304               1.573642
# 001602                 1.518046               1.169254
# 001603                 1.651020               1.329819
# 001604                 1.452757               1.757461
# 001605                 1.754717               1.288466
#
#         heat_5.497787143782138  v_pari_energy  pressure_energy  \
# 001586                1.140967    298459936.0     8.827066e+09
# 001587                1.024807    293689792.0     8.868789e+09
# 001588                0.760005    289034368.0     8.910569e+09
# 001589                1.004102    285795072.0     8.953183e+09
# 001590                0.815057    284338560.0     8.997167e+09
# ...                        ...            ...              ...
# 001601                1.328750    279299424.0     9.575882e+09
# 001602                1.294782    277397792.0     9.626330e+09
# 001603                1.529220    275658912.0     9.672675e+09
# 001604                1.784571    274469248.0     9.711355e+09
# 001605                1.244761    273920704.0     9.745953e+09
#
#         electrostatic_energy  magnetic_energy  total_energy
# 001586          2.137481e+08              0.0  9.339275e+09
# 001587          2.301409e+08              0.0  9.392619e+09
# 001588          2.495331e+08              0.0  9.449137e+09
# 001589          2.735518e+08              0.0  9.512530e+09
# 001590          3.030650e+08              0.0  9.584570e+09
# ...                      ...              ...           ...
# 001601          3.641453e+08              0.0  1.021933e+10
# 001602          3.512855e+08              0.0  1.025501e+10
# 001603          3.120121e+08              0.0  1.026035e+10
# 001604          2.609314e+08              0.0  1.024676e+10
# 001605          2.181670e+08              0.0  1.023804e+10
#
# [63 rows x 77 columns]

# %%
len(df.keys())
# Out:
# 77

# %%
num_plots_y = len(df.keys()) // 3 + 1
plt.figure(figsize=(15, 3*num_plots_y))
for i, key in enumerate(df.keys()):
    plt.subplot(num_plots_y, 3, i+1)
    plt.plot(df.reset_index()[key])
    plt.xlabel('time_step')
    plt.ylabel('numerical value')
    plt.title(key)

# %%
import numpy as np
a = [0,1]
b = [2,3]
c = [4,5,6]
s, g, h =np.meshgrid(a, b, c)
print(np.concatenate([s.reshape((-1,1)), g.reshape((-1,1)), h.reshape((-1,1))], axis=1))
# Out:
# [[0 2 4]
#  [0 2 5]
#  [0 2 6]
#  [1 2 4]
#  [1 2 5]
#  [1 2 6]
#  [0 3 4]
#  [0 3 5]
#  [0 3 6]
#  [1 3 4]
#  [1 3 5]
#  [1 3 6]]
